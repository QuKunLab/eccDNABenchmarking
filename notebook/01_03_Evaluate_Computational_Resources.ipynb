# %% [markdown]
# ## Section1 Part3 Evaluate Computational Resources
#
# #### Songwen Luo

# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
from matplotlib import font_manager
import seaborn as sns
sns.set()
from matplotlib.ticker import MultipleLocator

# %%
for font in font_manager.fontManager.ttflist:
        # 查看字体名以及对应的字体文件名
    print(font.name, '-', font.fname)
# Out:
# DejaVu Sans - /home/qukun/xuhao/miniconda3/envs/ce/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-BoldOblique.ttf
# DejaVu Serif - /home/qukun/xuhao/miniconda3/envs/ce/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif.ttf
# STIXSizeTwoSym - /home/qukun/xuhao/miniconda3/envs/ce/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymBol.ttf
# DejaVu Serif - /home/qukun/xuhao/miniconda3/envs/ce/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Italic.ttf
# DejaVu Sans - /home/qukun/xuhao/miniconda3/envs/ce/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Bold.ttf
# DejaVu Sans Mono - /home/qukun/xuhao/miniconda3/envs/ce/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Bold.ttf
# cmmi10 - /home/qukun/xuhao/miniconda3/envs/ce/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/cmmi10.ttf
# ...

# %%
# NGS_dataset1-dataset7 pipeline 平均时间消耗量

x = [5,10,15,20,25,30,35,40,45,50]  # x坐标
y1 = [6.6, 12.3, 18.2, 24.4, 30.5, 36.6, 43.1, 48.9, 54.8, 61.0] # y1坐标
y2 = [135.7, 311.3, 474.7, 578.9, 667.5, 756.2, 831.1, 878.3, 960.3, 1017.9] # y2坐标
y3 = [731.7, 815, 719.3, 657.2, 595.8, 633.6, 574.0, 595.7, 545.0, 557.2] #y3坐标
y4 = [4.4, 8.6, 12.8, 17.2, 21.5, 25.9, 30.2, 34.6, 39.0, 43.4] #y4坐标
y5 = [444.3, 545.3, 760.4, 807.7, 744.2, 865.9, 1049.4, 724.1, 901.0, 940.5] # y5坐标
y6 = [213.0, 209.6, 191.8, 186.2, 185.8, 174.8, 173.3, 186.0, 186.7, 174.5] # y6坐标


sem1 = np.array([3.2, 6.3, 9.5, 13.1, 16.6, 19.9, 23.7, 27.1, 30.4, 33.8])
sem2 = np.array([30.7, 87.0, 125.0, 150.7, 176.2, 208.5, 229.0, 245.6, 272.5, 295.8])
sem3 = np.array([125.2, 117.5, 119.1, 136.7, 108.1, 95.0, 87.8, 81.4, 59.6, 51.8])
sem4 = np.array([2.1, 4.3, 6.5, 8.9, 11.1, 13.3, 15.6, 17.9, 20.3, 22.6])
sem5 = np.array([50.8, 98.2, 145.8, 189.1, 225.5, 238.9, 284.8, 157.4, 303.1, 317.7])
sem6 = np.array([46.1, 54.0, 52.1, 49.2, 55.6, 51.1, 42.7, 51.7, 55.7, 55.1])

fig=plt.figure()
fig.patch.set_facecolor('white')#设置背景颜色
fig.patch.set_alpha(1)#设置透明度
bwith = 2 #边框宽度设置为2
ax = plt.gca()#获取边框
#设置边框
ax.spines['bottom'].set_linewidth(bwith)#图框下边
ax.spines['left'].set_linewidth(bwith)#图框左边
ax.spines['top'].set_linewidth(bwith)#图框上边
ax.spines['right'].set_linewidth(bwith)#图框右边
ax.spines['bottom'].set_color('black')
ax.spines['left'].set_color('black')
ax.spines['top'].set_color('black')
ax.spines['right'].set_color('black')
ax.set_facecolor('white')
plt.grid(color = 'black',linestyle='-')
plt.grid(False)
values = list(range(3,153,15))
plt.plot(values, y1, lw=1, c='#e66760', marker='o', markersize=3, label='ecc_finder(map-sr)')  # 绘制y1
plt.plot(values, y2, lw=1, c='#FFB7B7', marker='o', markersize=3, label='ecc_finder(asm-sr)')  # 绘制y2
plt.plot(values, y3, lw=1, c='#2a6ebb', marker='o', markersize=3, label='ECCsplorer') # 绘制y3
plt.plot(values, y4, lw=1, c='#16a085', marker='o', markersize=3, label='Circle_finder(bwa-mem-samblaster)')# 绘制y4
plt.plot(values, y5, lw=1, c='#254C2A', marker='o', markersize=3, label='Circle_finder(microDNA-InOne)')# 绘制y5
plt.plot(values, y6, lw=1, c='#96588a', marker='o', markersize=3, label='Circle_Map')# 绘制y6

plt.errorbar(values, y1, yerr=sem1, fmt='none', linewidth=0.5, ecolor='#e66760',elinewidth=1, capsize=4)
plt.errorbar(values, y2, yerr=sem2, fmt='none', linewidth=0.5, ecolor='#FFB7B7',elinewidth=1, capsize=4)
plt.errorbar(values, y3, yerr=sem3, fmt='none', linewidth=0.5, ecolor='#2a6ebb',elinewidth=1, capsize=4)
plt.errorbar(values, y4, yerr=sem4, fmt='none', linewidth=0.5, ecolor='#16a085',elinewidth=1, capsize=4)
plt.errorbar(values, y5, yerr=sem5, fmt='none', linewidth=0.5, ecolor='#254C2A',elinewidth=1, capsize=4)
plt.errorbar(values, y6, yerr=sem6, fmt='none', linewidth=0.5, ecolor='#96588a',elinewidth=1, capsize=4)

# plt-style 
plt.xlim(0, 141)  # x轴坐标范围
plt.ylim(0, 10000)  # y轴坐标范围
plt.xticks(values, x)  # x轴的刻度
plt.yscale('symlog',linthresh=1)
#plt.ylabel('symlogy')
plt.tick_params(top=False,bottom=True,left=True,right=False)
plt.tick_params(direction="out",width=1,length=4)
#plt.tick_params(axis='both',which='major',labelsize=14)
#plt.grid(False)
#plt.autoscale()
plt.xlabel('Mean Coverage of eccDNA')  # x轴标注
plt.ylabel('Time(min)')  # y轴标注
plt.legend(loc = 5,facecolor='white',bbox_to_anchor=(1.7, 0.5))  # 图例
#pdf文字格式修改
font_manager.fontManager.addfont('/home/qukun/liuke/miniconda3/fonts/Arial.ttf')
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
plt.rcParams['font.serif'] = ['Arial']
#plt.savefig('e:/test.png')  # 保存图片
plt.savefig("/home/qukun/luosongwen/workspace/eccDNA/scripts/Revise/NGS_dataset_time_cost.pdf",bbox_inches='tight')
plt.show()

# %%
# NGS_dataset1-dataset7 pipeline 平均内存消耗量
x = [5,10,15,20,25,30,35,40,45,50]  # x坐标
y1 = [10.4, 14.4, 18.4, 22.2, 25.9, 29.8, 33.2, 37.1, 41.3, 45.1] # y1坐标
y2 = [22.0, 25.4, 28.3, 31.6, 35.1, 38.7, 42.4, 46.2, 49.9, 53.9] # y2坐标
y3 = [61.3, 77.6, 58.6, 87.6, 113.4, 129.3, 134.6, 157.7, 131.4, 203.7] #y3坐标
y4 = [8.1, 10.4, 12.2, 13.7, 14.3, 14.7, 14.9, 15.5, 16.0, 16.5] #y4坐标
y5 = [3.3, 4.8, 7.0, 8.3, 8.7, 8.9, 9.7, 10.2, 10.6, 11.1] # y5坐标
y6 = [18.7, 19.1, 20.0, 20.0, 20.5, 21.2, 20.5, 20.9, 20.4, 19.7] # y6坐标

sem1 = np.array([1.6, 4.1, 6.5, 9.2, 11.8, 14.9, 17.3, 19.9, 22.8, 25.3])
sem2 = np.array([1.1, 3.1, 5.1, 7.0, 8.8, 10.6, 12.2, 13.9, 15.4, 16.8])
sem3 = np.array([4.2, 20.5, 1.7, 28.5, 28.9, 20.6, 41.1, 36.3, 21.4, 21.3])
sem4 = np.array([1.2, 1.5, 2.2, 3.1, 3.0, 3.0, 2.8, 2.8, 2.8, 2.7])
sem5 = np.array([1.0, 2.0, 3.1, 3.9, 3.9, 4.0, 3.9, 4.0, 4.0, 4.0])
sem6 = np.array([0.7, 0.3, 0.9, 2.3, 2.0, 2.0, 2.2, 2.2, 2.1, 2.5])

fig=plt.figure()
fig.patch.set_facecolor('white')#设置背景颜色
fig.patch.set_alpha(1)#设置透明度
bwith = 2 #边框宽度设置为2
ax = plt.gca()#获取边框
#设置边框
ax.spines['bottom'].set_linewidth(bwith)#图框下边
ax.spines['left'].set_linewidth(bwith)#图框左边
ax.spines['top'].set_linewidth(bwith)#图框上边
ax.spines['right'].set_linewidth(bwith)#图框右边
ax.spines['bottom'].set_color('black')
ax.spines['left'].set_color('black')
ax.spines['top'].set_color('black')
ax.spines['right'].set_color('black')
ax.set_facecolor('white')
plt.grid(color = 'black',linestyle='-')
plt.grid(False)

values = list(range(3,153,15))
plt.plot(values, y1, lw=1, c='#e66760', marker='o', markersize=3, label='ecc_finder(map-sr)')  # 绘制y1
plt.plot(values, y2, lw=1, c='#FFB7B7', marker='o', markersize=3, label='ecc_finder(asm-sr)')  # 绘制y2
plt.plot(values, y3, lw=1, c='#2a6ebb', marker='o', markersize=3, label='ECCsplorer') # 绘制y3
plt.plot(values, y4, lw=1, c='#16a085', marker='o', markersize=3, label='Circle_finder(bwa-mem-samblaster)')# 绘制y4
plt.plot(values, y5, lw=1, c='#254C2A', marker='o', markersize=3, label='Circle_finder(microDNA-InOne)')# 绘制y5
plt.plot(values, y6, lw=1, c='#96588a', marker='o', markersize=3, label='Circle_Map')# 绘制y6

plt.errorbar(values, y1, yerr=sem1, fmt='none', linewidth=0.5, ecolor='#e66760',elinewidth=1, capsize=4)
plt.errorbar(values, y2, yerr=sem2, fmt='none', linewidth=0.5, ecolor='#FFB7B7',elinewidth=1, capsize=4)
plt.errorbar(values, y3, yerr=sem3, fmt='none', linewidth=0.5, ecolor='#2a6ebb',elinewidth=1, capsize=4)
plt.errorbar(values, y4, yerr=sem4, fmt='none', linewidth=0.5, ecolor='#16a085',elinewidth=1, capsize=4)
plt.errorbar(values, y5, yerr=sem5, fmt='none', linewidth=0.5, ecolor='#254C2A',elinewidth=1, capsize=4)
plt.errorbar(values, y6, yerr=sem6, fmt='none', linewidth=0.5, ecolor='#96588a',elinewidth=1, capsize=4)

# plt-style 
plt.xlim(0, 141)  # x轴坐标范围
plt.ylim(0, 300)  # y轴坐标范围
plt.xticks(values, x)  # x轴的刻度
plt.tick_params(top=False,bottom=True,left=True,right=False)
plt.tick_params(direction="out",width=1,length=4)
#plt.yscale('symlog')
#plt.autoscale()
plt.xlabel('Mean Coverage of eccDNA')  # x轴标注
plt.ylabel('Space(GB)')  # y轴标注
plt.legend(loc = 5,facecolor='white',bbox_to_anchor=(1.7, 0.5))  # 图例
#pdf文字格式修改
font_manager.fontManager.addfont('/home/qukun/liuke/miniconda3/fonts/Arial.ttf')
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
plt.rcParams['font.serif'] = ['Arial']
#plt.savefig('e:/test.png')  # 保存图片
plt.savefig("/home/qukun/luosongwen/workspace/eccDNA/scripts/Revise/NGS_dataset_space_cost.pdf",bbox_inches='tight')
plt.show()

# %%
# TGS dataset1-dataset7 pipeline 时间消耗量
x = [5,10,15,20,25,30,35,40,45,50]  # x坐标
y1 = [3.8, 4.3, 5.0, 5.7, 6.4, 7.3, 7.9, 8.7, 9.3, 10.0] # y1坐标
y2 = [3.8, 12.5, 25.6, 43.4, 110.4, 151.1, 195.4, 239.5, 293.0, 337.0] # y2坐标
y3 = [3.2, 5.2, 7.4, 9.3, 11.1, 13.2, 14.9, 16.7, 18.4, 20.6] #y5坐标
y4 = [9.7, 13.3, 17.0, 20.3, 23.7, 27.2, 30.5, 33.3, 36.6, 40.0] #y4坐标
y5 = [343.3, 447.6, 496.8, 526.8, 556.5, 581.9, 603.1, 625.0, 642.8, 672.1] # y3坐标


sem1 = np.array([0.3, 0.6, 0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 2.8])
sem2 = np.array([0.6, 2.0, 4.2, 7.1, 48.4, 66.0, 82.5, 97.0, 117.1, 125.3])
sem3 = np.array([0.5, 0.8, 0.6, 0.9, 1.0, 1.3, 1.3, 1.5, 1.6, 1.9])
sem4 = np.array([2.1, 3.4, 4.7, 5.9, 7.1, 8.5, 9.7, 10.8, 12.2, 13.3])
sem5 = np.array([109.2, 146.7, 161.1, 169.4, 174.5, 178.5, 181.5, 185.1, 189.5, 200.2])

fig=plt.figure()
fig.patch.set_facecolor('white')#设置背景颜色
fig.patch.set_alpha(1)#设置透明度
bwith = 2 #边框宽度设置为2
ax = plt.gca()#获取边框
#设置边框
ax.spines['bottom'].set_linewidth(bwith)#图框下边
ax.spines['left'].set_linewidth(bwith)#图框左边
ax.spines['top'].set_linewidth(bwith)#图框上边
ax.spines['right'].set_linewidth(bwith)#图框右边
ax.spines['bottom'].set_color('black')
ax.spines['left'].set_color('black')
ax.spines['top'].set_color('black')
ax.spines['right'].set_color('black')
ax.set_facecolor('white')
plt.grid(color = 'black',linestyle='-')
plt.grid(False)
values = list(range(3,153,15))
plt.plot(values, y1, lw=1, c='#e66760', marker='o', markersize=3, label='ecc_finder(map-ont)')  # 绘制y1
plt.plot(values, y2, lw=1, c='#FFB7B7', marker='o', markersize=3, label='ecc_finder(asm-ont)')  # 绘制y2
plt.plot(values, y3, lw=1, c='#1da1f2', marker='o', markersize=3, label='eccDNA_RCA_nanopore') # 绘制y3
plt.plot(values, y4, lw=1, c='#99cc33', marker='o', markersize=3, label='NanoCircle')# 绘制y4
plt.plot(values, y5, lw=1, c='#9146ff', marker='o', markersize=3, label='CReSIL')# 绘制y5
plt.errorbar(values, y1, yerr=sem1, fmt='none', linewidth=0.5, ecolor='#e66760',elinewidth=1, capsize=4)
plt.errorbar(values, y2, yerr=sem2, fmt='none', linewidth=0.5, ecolor='#FFB7B7',elinewidth=1, capsize=4)
plt.errorbar(values, y3, yerr=sem3, fmt='none', linewidth=0.5, ecolor='#1da1f2',elinewidth=1, capsize=4)
plt.errorbar(values, y4, yerr=sem4, fmt='none', linewidth=0.5, ecolor='#99cc33',elinewidth=1, capsize=4)
plt.errorbar(values, y5, yerr=sem5, fmt='none', linewidth=0.5, ecolor='#9146ff',elinewidth=1, capsize=4)

# plt-style 
plt.xlim(0, 141)  # x轴坐标范围
plt.ylim(0, 10000)  # y轴坐标范围
plt.xticks(values, x)  # x轴的刻度
plt.tick_params(top=False,bottom=True,left=True,right=False)
plt.tick_params(direction="out",width=1,length=4)
plt.yscale('symlog',linthresh=1)
#plt.autoscale()
plt.xlabel('Mean Coverage of eccDNA')  # x轴标注
plt.ylabel('Time(min)')  # y轴标注
plt.legend(loc = 5,facecolor='white',bbox_to_anchor=(1.58, 0.5))  # 图例
#pdf文字格式修改
font_manager.fontManager.addfont('/home/qukun/liuke/miniconda3/fonts/Arial.ttf')
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
plt.rcParams['font.serif'] = ['Arial']
#plt.savefig('e:/test.png')  # 保存图片
plt.savefig("/home/qukun/luosongwen/workspace/eccDNA/scripts/Revise/TGS_dataset_time_cost.pdf",bbox_inches='tight')
plt.show()

# %%
# TGS dataset1-dataset7 pipeline 内存消耗量
x = [5,10,15,20,25,30,35,40,45,50]  # x坐标
y1 = [10.0, 10.1, 9.8, 10.3, 10.2, 10.2, 10.6, 10.4, 10.6, 10.5] # y1坐标
y2 = [2.1, 2.4, 2.2, 1.4, 2.1, 2.2, 2.4, 2.5, 2.6, 2.5] # y2坐标
y3 = [11.7, 11.9, 12.0, 12.4, 12.5, 12.2, 12.5, 12.3, 12.5, 12.6] #y3坐标
y4 = [11.8, 12.6, 13.1, 13.7, 13.9, 14.2, 14.2, 14.2, 14.3, 14.4] #y4坐标
y5 = [10.6, 11.3, 12.5, 13.6, 12.8, 14.0, 14.7, 14.8, 15.0, 15.6] # y5坐标

sem1 = np.array([0.3, 0.3, 0.2, 0.2, 0.3, 0.3, 0.2, 0.2, 0.3, 0.2])
sem2 = np.array([0.8, 0.9, 0.8, 0.5, 0.8, 0.8, 0.9, 0.9, 1.0, 0.9])
sem3 = np.array([0.4, 0.4, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5])
sem4 = np.array([0.7, 0.7, 0.6, 0.6, 0.6, 0.6, 0.5, 0.5, 0.6, 0.6])
sem5 = np.array([0.8, 0.9, 1.6, 2.8, 1.6, 2.8, 3.8, 3.5, 3.7, 4.4])

fig=plt.figure()
fig.patch.set_facecolor('white')#设置背景颜色
fig.patch.set_alpha(1)#设置透明度
bwith = 2 #边框宽度设置为2
ax = plt.gca()#获取边框
#设置边框
ax.spines['bottom'].set_linewidth(bwith)#图框下边
ax.spines['left'].set_linewidth(bwith)#图框左边
ax.spines['top'].set_linewidth(bwith)#图框上边
ax.spines['right'].set_linewidth(bwith)#图框右边
ax.spines['bottom'].set_color('black')
ax.spines['left'].set_color('black')
ax.spines['top'].set_color('black')
ax.spines['right'].set_color('black')
ax.set_facecolor('white')
plt.grid(color = 'black',linestyle='-')
plt.grid(False)
values = list(range(3,153,15))
plt.plot(values, y1, lw=1, c='#e66760', marker='o',markersize=3, label='ecc_finder(map-ont)')  # 绘制y1
plt.plot(values, y2, lw=1, c='#FFB7B7', marker='o',markersize=3, label='ecc_finder(asm-ont)')  # 绘制y2
plt.plot(values, y3, lw=1, c='#1da1f2', marker='o',markersize=3, label='eccDNA_RCA_nanopore') # 绘制y3
plt.plot(values, y4, lw=1, c='#99cc33', marker='o',markersize=3, label='NanoCircle')# 绘制y4
plt.plot(values, y5, lw=1, c='#9146ff', marker='o',markersize=3, label='CReSIL')# 绘制y5
plt.errorbar(values, y1, yerr=sem1, fmt='none', linewidth=0.5, ecolor='#e66760',elinewidth=1, capsize=4)
plt.errorbar(values, y2, yerr=sem2, fmt='none', linewidth=0.5, ecolor='#FFB7B7',elinewidth=1, capsize=4)
plt.errorbar(values, y3, yerr=sem3, fmt='none', linewidth=0.5, ecolor='#1da1f2',elinewidth=1, capsize=4)
plt.errorbar(values, y4, yerr=sem4, fmt='none', linewidth=0.5, ecolor='#99cc33',elinewidth=1, capsize=4)
plt.errorbar(values, y5, yerr=sem5, fmt='none', linewidth=0.5, ecolor='#9146ff',elinewidth=1, capsize=4)
# plt-style 
plt.xlim(0, 141)  # x轴坐标范围
plt.ylim(0, 25)  # y轴坐标范围
plt.xticks(values, x)  # x轴的刻度
plt.tick_params(top=False,bottom=True,left=True,right=False)
plt.tick_params(direction="out",width=1,length=4)
#plt.yscale('symlog')
#plt.autoscale()
plt.xlabel('Mean Coverage of eccDNA')  # x轴标注
plt.ylabel('Space(GB)')  # y轴标注
plt.legend(loc = 5,facecolor='white',bbox_to_anchor=(1.58, 0.5))  # 图例
#pdf文字格式修改
font_manager.fontManager.addfont('/home/qukun/liuke/miniconda3/fonts/Arial.ttf')
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
plt.rcParams['font.serif'] = ['Arial']
#plt.savefig('e:/test.png')  # 保存图片
plt.savefig("/home/qukun/luosongwen/workspace/eccDNA/scripts/Revise/TGS_dataset_space_cost.pdf",bbox_inches='tight')
plt.show()
